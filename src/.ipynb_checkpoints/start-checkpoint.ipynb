# %%
import sys
import os

# Aggiunge la cartella 'src' relativa alla posizione dello script
sys.path.append(os.path.abspath("src"))

# %%
from iso2neo4j import PlantDataImporter
importer = PlantDataImporter("neo4j://neo4j","neo4j","password")
importer.import_plant_data("../data/acme-plant.json")

# %%
from graphrag-app import GraphRAGApp
app = GraphRAGApp("neo4j://neo4j",("neo4j","password"))
app.chat_with_rag("Extract cases belong to machine PUMP-1 after march 2025")
